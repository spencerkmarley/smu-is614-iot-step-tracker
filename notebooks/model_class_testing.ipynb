# %% [markdown]
# ### Objective
#
# - Testing the BaseModel class that will be loaded into a CrossValidator object

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from src.config import MLCONFIG
from sklearn import datasets
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# basemodel class from model.py 
from src.model import BaseModel

# %%
# load some sample data
iris = datasets.load_iris() 
X = pd.DataFrame(iris.data[:, :2], columns=["a", "b"])
y = iris.target

# %%
# setup the hyperparameter grid
log_reg_param_grid = {
    "clf": [LogisticRegression(max_iter=1000, solver="liblinear")],
    # regularization param: higher C = less regularization
    "clf__C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    # specifies kernel type to be used
    "clf__penalty": ["l1", "l2"]
}

# %%
# build the pipe
mm_scale = MinMaxScaler(feature_range=(0, 1))
mdl = BaseModel()

log_reg_pipe = Pipeline([("mm", mm_scale), ("clf", mdl)])

# %%
# perform a gridsearchCV 
log_reg_cv = GridSearchCV(
        estimator=log_reg_pipe,
        param_grid=log_reg_param_grid,
        scoring=MLCONFIG.BASE_SCORER,
        refit="F_score",
        cv=MLCONFIG.CV_SPLIT,
        return_train_score=True,
        n_jobs=-1,
        verbose=10,
    )

# fitting model
log_reg_cv.fit(X, y)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5; 1/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1
# [CV 2/5; 1/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1
# [CV 3/5; 1/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1
# [CV 1/5; 1/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 4/5; 1/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1
# [CV 5/5; 1/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1
# [CV 1/5; 2/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2
# [CV 2/5; 1/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 3/5; 1/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 2/5; 2/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2
# [CV 4/5; 1/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 3/5; 2/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2
# [CV 4/5; 2/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2
# [CV 5/5; 2/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2
# [CV 1/5; 3/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1
# [CV 2/5; 3/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1
# [CV 1/5; 2/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2; AUC: (train=0.897, test=0.868) F_score: (train=0.524, test=0.556) total time=   0.0s
# [CV 3/5; 3/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1
# [CV 4/5; 2/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2; AUC: (train=0.906, test=0.857) F_score: (train=0.531, test=0.531) total time=   0.0s
# [CV 4/5; 3/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1
# [CV 1/5; 3/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 2/5; 3/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 5/5; 3/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1
# [CV 1/5; 4/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2
# [CV 2/5; 2/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2; AUC: (train=0.885, test=0.897) F_score: (train=0.511, test=0.531) total time=   0.0s
# [CV 3/5; 3/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 3/5; 2/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2; AUC: (train=0.899, test=0.862) F_score: (train=0.518, test=0.505) total time=   0.0s
# [CV 2/5; 4/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2
# [CV 4/5; 4/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2
# [CV 1/5; 5/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1
# [CV 5/5; 1/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 5/5; 3/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 5/5; 2/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.001, clf__penalty=l2; AUC: (train=0.877, test=0.910) F_score: (train=0.531, test=0.556) total time=   0.0s
# [CV 3/5; 5/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1
# [CV 5/5; 5/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1
# [CV 2/5; 6/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2
# [CV 4/5; 4/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2; AUC: (train=0.904, test=0.857) F_score: (train=0.556, test=0.556) total time=   0.0s
# [CV 5/5; 4/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2
# [CV 1/5; 4/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2; AUC: (train=0.896, test=0.867) F_score: (train=0.556, test=0.556) total time=   0.0s
# [CV 4/5; 6/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2
# [CV 1/5; 5/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1; AUC: (train=0.801, test=0.818) F_score: (train=0.490, test=0.500) total time=   0.0s
# [CV 5/5; 5/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1; AUC: (train=0.805, test=0.803) F_score: (train=0.484, test=0.516) total time=   0.0s
# [CV 2/5; 5/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1
# [CV 1/5; 6/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2
# [CV 2/5; 6/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2; AUC: (train=0.883, test=0.892) F_score: (train=0.642, test=0.780) total time=   0.0s
# [CV 3/5; 6/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2
# [CV 3/5; 5/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1; AUC: (train=0.804, test=0.812) F_score: (train=0.479, test=0.447) total time=   0.0s
# [CV 4/5; 5/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1
# [CV 2/5; 5/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1; AUC: (train=0.811, test=0.780) F_score: (train=0.473, test=0.470) total time=   0.0s
# [CV 1/5; 7/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1
# [CV 4/5; 3/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l1; AUC: (train=0.500, test=0.500) F_score: (train=0.167, test=0.167) total time=   0.0s
# [CV 3/5; 7/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1
# [CV 1/5; 6/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2; AUC: (train=0.896, test=0.865) F_score: (train=0.657, test=0.683) total time=   0.0s
# [CV 5/5; 7/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1
# [CV 4/5; 6/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2; AUC: (train=0.906, test=0.860) F_score: (train=0.657, test=0.624) total time=   0.0s
# [CV 5/5; 6/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2
# [CV 1/5; 7/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1; AUC: (train=0.923, test=0.898) F_score: (train=0.798, test=0.722) total time=   0.0s
# [CV 2/5; 7/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1
# [CV 5/5; 4/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2; AUC: (train=0.875, test=0.912) F_score: (train=0.551, test=0.624) total time=   0.0s
# [CV 2/5; 8/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2
# [CV 2/5; 4/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2; AUC: (train=0.883, test=0.895) F_score: (train=0.543, test=0.556) total time=   0.0s
# [CV 4/5; 5/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l1; AUC: (train=0.801, test=0.825) F_score: (train=0.471, test=0.477) total time=   0.0s
# [CV 3/5; 4/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2
# [CV 4/5; 8/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2
# [CV 3/5; 6/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2; AUC: (train=0.899, test=0.865) F_score: (train=0.657, test=0.683) total time=   0.0s
# [CV 1/5; 9/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1
# [CV 5/5; 7/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1; AUC: (train=0.901, test=0.982) F_score: (train=0.782, test=0.861) total time=   0.0s
# [CV 1/5; 8/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2
# [CV 4/5; 8/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2; AUC: (train=0.925, test=0.860) F_score: (train=0.792, test=0.626) total time=   0.0s
# [CV 3/5; 4/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.01, clf__penalty=l2; AUC: (train=0.898, test=0.862) F_score: (train=0.537, test=0.556) total time=   0.0s
# [CV 5/5; 8/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2
# [CV 3/5; 9/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1
# [CV 5/5; 6/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=0.1, clf__penalty=l2; AUC: (train=0.875, test=0.913) F_score: (train=0.662, test=0.734) total time=   0.0s
# [CV 5/5; 9/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1
# [CV 3/5; 7/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1; AUC: (train=0.927, test=0.890) F_score: (train=0.815, test=0.766) total time=   0.0s
# [CV 4/5; 7/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1
# [CV 2/5; 8/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2; AUC: (train=0.902, test=0.917) F_score: (train=0.754, test=0.800) total time=   0.0s
# [CV 3/5; 8/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2
# [CV 5/5; 8/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2; AUC: (train=0.889, test=0.948) F_score: (train=0.761, test=0.775) total time=   0.0s
# [CV 1/5; 9/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1; AUC: (train=0.930, test=0.902) F_score: (train=0.834, test=0.722) total time=   0.0s
# [CV 2/5; 9/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1
# [CV 5/5; 9/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1; AUC: (train=0.903, test=0.992) F_score: (train=0.792, test=0.898) total time=   0.0s
# [CV 1/5; 10/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2
# [CV 3/5; 9/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1; AUC: (train=0.931, test=0.883) F_score: (train=0.817, test=0.733) total time=   0.0s
# [CV 2/5; 10/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2
# [CV 4/5; 9/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1
# [CV 3/5; 8/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2; AUC: (train=0.919, test=0.883) F_score: (train=0.755, test=0.794) total time=   0.0s
# [CV 4/5; 10/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2
# [CV 2/5; 9/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1; AUC: (train=0.918, test=0.923) F_score: (train=0.792, test=0.833) total time=   0.0s
# [CV 1/5; 10/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2; AUC: (train=0.923, test=0.888) F_score: (train=0.824, test=0.722) total time=   0.0s
# [CV 5/5; 10/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2
# [CV 2/5; 7/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1; AUC: (train=0.915, test=0.918) F_score: (train=0.806, test=0.800) total time=   0.0s
# [CV 1/5; 11/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1
# [CV 2/5; 11/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1
# [CV 4/5; 9/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l1; AUC: (train=0.928, test=0.885) F_score: (train=0.833, test=0.722) total time=   0.0s
# [CV 3/5; 11/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1
# [CV 1/5; 8/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l2; AUC: (train=0.915, test=0.883) F_score: (train=0.774, test=0.707) total time=   0.0s
# [CV 4/5; 11/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1
# [CV 2/5; 10/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2; AUC: (train=0.914, test=0.922) F_score: (train=0.782, test=0.833) total time=   0.0s
# [CV 3/5; 10/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2
# [CV 4/5; 7/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1, clf__penalty=l1; AUC: (train=0.928, test=0.885) F_score: (train=0.797, test=0.722) total time=   0.0s
# [CV 5/5; 10/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2; AUC: (train=0.899, test=0.978) F_score: (train=0.781, test=0.898) total time=   0.0s
# [CV 5/5; 11/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1
# [CV 1/5; 12/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2
# [CV 1/5; 11/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1; AUC: (train=0.932, test=0.898) F_score: (train=0.841, test=0.722) total time=   0.0s
# [CV 2/5; 12/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2
# [CV 3/5; 11/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1; AUC: (train=0.931, test=0.882) F_score: (train=0.825, test=0.733) total time=   0.0s
# [CV 3/5; 12/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2
# [CV 1/5; 12/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2; AUC: (train=0.929, test=0.897) F_score: (train=0.834, test=0.722) total time=   0.0s
# [CV 4/5; 12/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2
# [CV 5/5; 11/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1; AUC: (train=0.904, test=0.990) F_score: (train=0.799, test=0.898) total time=   0.0s
# [CV 5/5; 12/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2
# [CV 4/5; 11/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1; AUC: (train=0.928, test=0.887) F_score: (train=0.833, test=0.722) total time=   0.0s
# [CV 1/5; 13/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1
# [CV 3/5; 12/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2; AUC: (train=0.928, test=0.887) F_score: (train=0.817, test=0.733) total time=   0.0s
# [CV 2/5; 13/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1
# [CV 5/5; 12/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2; AUC: (train=0.902, test=0.992) F_score: (train=0.782, test=0.898) total time=   0.0s
# [CV 3/5; 10/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2; AUC: (train=0.927, test=0.885) F_score: (train=0.815, test=0.766) total time=   0.0s
# [CV 3/5; 13/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1
# [CV 4/5; 13/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1
# [CV 2/5; 11/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l1; AUC: (train=0.919, test=0.927) F_score: (train=0.799, test=0.833) total time=   0.0s
# [CV 4/5; 12/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2; AUC: (train=0.927, test=0.872) F_score: (train=0.833, test=0.722) total time=   0.0s
# [CV 5/5; 13/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1
# [CV 4/5; 10/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=10, clf__penalty=l2; AUC: (train=0.927, test=0.863) F_score: (train=0.805, test=0.722) total time=   0.0s
# [CV 1/5; 14/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2[CV 1/5; 13/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1; AUC: (train=0.932, test=0.898) F_score: (train=0.841, test=0.722) total time=   0.0s
# [CV 2/5; 12/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=100, clf__penalty=l2; AUC: (train=0.917, test=0.920) F_score: (train=0.782, test=0.833) total time=   0.0s
#
# [CV 3/5; 14/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2
# [CV 4/5; 14/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2
# [CV 2/5; 14/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2
# [CV 3/5; 13/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1; AUC: (train=0.931, test=0.882) F_score: (train=0.825, test=0.733) total time=   0.0s
# [CV 5/5; 14/14] START clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2
# [CV 2/5; 13/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1; AUC: (train=0.919, test=0.927) F_score: (train=0.799, test=0.833) total time=   0.0s
# [CV 4/5; 13/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1; AUC: (train=0.928, test=0.885) F_score: (train=0.833, test=0.722) total time=   0.0s
# [CV 5/5; 13/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l1; AUC: (train=0.905, test=0.990) F_score: (train=0.799, test=0.898) total time=   0.0s
# [CV 3/5; 14/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2; AUC: (train=0.931, test=0.883) F_score: (train=0.817, test=0.733) total time=   0.0s
# [CV 2/5; 14/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2; AUC: (train=0.919, test=0.927) F_score: (train=0.792, test=0.833) total time=   0.0s
# [CV 1/5; 14/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2; AUC: (train=0.932, test=0.898) F_score: (train=0.834, test=0.722) total time=   0.0s
# [CV 4/5; 14/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2; AUC: (train=0.927, test=0.885) F_score: (train=0.833, test=0.722) total time=   0.0s
# [CV 5/5; 14/14] END clf=LogisticRegression(max_iter=1000, solver='liblinear'), clf__C=1000, clf__penalty=l2; AUC: (train=0.904, test=0.990) F_score: (train=0.799, test=0.898) total time=   0.0s
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=5, random_state=123, test_size=0.2,
#             train_size=0.8),
#              estimator=Pipeline(steps=[('mm', MinMaxScaler()),
#                                        ('clf', BaseModel())]),
#              n_jobs=-1,
#              param_grid={'clf': [LogisticRegression(C=10, max_iter=1000,
#                                                     solver='liblinear')],
#                          'clf__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'clf__penalty': ['l1', 'l2']},
#              refit='F_score', return_train_score=True,
#              scoring={'AUC': 'roc_auc_ovr', 'F_score': 'f1_weighted'},
#              verbose=10)

# %%
print(log_reg_cv.best_estimator_)
print(log_reg_cv.best_params_)
# Out:
# Pipeline(steps=[('mm', MinMaxScaler()),
#                 ('clf',
#                  LogisticRegression(C=10, max_iter=1000, solver='liblinear'))])
# {'clf': LogisticRegression(C=10, max_iter=1000, solver='liblinear'), 'clf__C': 10, 'clf__penalty': 'l2'}
